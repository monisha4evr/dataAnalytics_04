# %%
#np.random.rand(3) (3,5)
#rand()
#randint()
#arr=np.array([1,2,3,4,5,6],dtype=np.int8) np.random.choice(arr)
# rng = np.random.default_rng() print("RandomFloat:",rng.random())
# colors = ["red", "green", "blue"] rng.choice(colors)
# rng.choice(10, size=5, replace=False)
# rng = np.random.default_rng(seed=42) print(rng.integers(1,10,5))

# %%
import numpy as np

# %%
np.random.rand(3)
# Out:
# array([0.15692543, 0.04008309, 0.65316821])

# %%
np.random.rand(3,5)
# Out:
# array([[0.70590271, 0.84170009, 0.98953749, 0.99660175, 0.69946053],
#        [0.60129223, 0.96625142, 0.66977799, 0.56940916, 0.51784347],
#        [0.17809684, 0.18292712, 0.7841871 , 0.15432338, 0.40407289]])

# %%
np.random.randint(3)
# Out:
# 0

# %%
arr=np.array([1,2,3,4,5,6],dtype=np.int8) 
np.random.choice(arr)
# Out:
# np.int8(5)

# %%
 rng = np.random.default_rng()

# %%
colors = ["red", "green", "blue"] 
rng.choice(colors)
# Out:
# np.str_('green')

# %%
rng.integers(10)
# Out:
# np.int64(2)

# %%
 rng.choice(10, size=10, replace=False)
# Out:
# array([8, 7, 2, 9, 4, 5, 1, 6, 3, 0])

# %%
 rng.choice(10, size=11, replace=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 rng.choice(10, size=11, replace=False)
#
# File numpy/random/_generator.pyx:925, in numpy.random._generator.Generator.choice()
# --> 925 'Could not get source, probably due dynamically evaluated source code.'
#
# ValueError: Cannot take a larger sample than population when replace is False

# %%
 rng.choice(10, size=11, replace=True)
# Out:
# array([7, 1, 4, 7, 2, 2, 3, 0, 1, 6, 7])
