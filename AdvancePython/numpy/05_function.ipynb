# %% [markdown]
# - Aggregation Functions (sum,mean,median,max,min,std,var,argmax)
# - random (random.rand(),random.randn(),random.randint(),random.seed())
# - sorting and unique
# - Joining & Spliting(concatenate(),vstack(),hstack(),split())
# - Load csv file(loadtxt,genfromtxt())

# %%
# Mean=Number of values/Sum of all values
# median - Middle value after Sorting
# std-Standard Deviation (spread of data).Small std → Values are close to the mean. Large std → Values are spread out.
# var-Variance=(Standard Deviation) 2

# %%
#np.random.rand(3) (3,5)
#rand()
#randint()
#arr=np.array([1,2,3,4,5,6],dtype=np.int8) np.random.choice(arr)
# rng = np.random.default_rng() print("RandomFloat:",rng.random())
# colors = ["red", "green", "blue"] rng.choice(colors)
# rng.choice(10, size=5, replace=False)
# rng = np.random.default_rng(seed=42) print(rng.integers(1,10,5))

# %%
#np.sort()
#print(np.sort(arr)[::-1])
#arr = np.array([[9,2],[5,8],[1,6]]) print(np.sort(arr, axis=0))
#argsort-> arr=np.array([50,20,80,10]) print(np.argsort(arr))
# names=np.array(["A","B","C","D"]) salary=np.array([50000,30000,70000,20000]) idx=np.argsort(salary) print(names[idx])
#----------------------------
# print(np.unique(arr)) # print(np.unique(arr,axis=0))
# duplicate Count=> u,c=np.unique(arr,return_counts=True)
# u,i=np.unique(arr,return_index=True)

# %% [raw]
# eye - Identity Matrix
# identity - Identity Matrix
# diag - Create Diagonal Matrix np.diag([10,20,30])
# where - Used for conditional selection. np.where(arr>20,"Greater","Smaller")
# clip - Restrict Value Between minimum and maximum range print(np.clip(arr, 10, 20))
# any - return True if any one is True Eg: arr=np.array([1,2,3,4,5]) print(np.all(arr > 3))
# all -Return True if Everything is True
# axis-Axis determines which direction NumPy performs the operation.

# %%
import numpy as np

# %%
data = np.genfromtxt(
    "../../../data.csv",
    delimiter=",",
    names=True,
    dtype=None,
    encoding="utf-8"
)

# %%
data=np.loadtxt('../../../sample_numpy.csv',delimiter=',',skiprows=1)
