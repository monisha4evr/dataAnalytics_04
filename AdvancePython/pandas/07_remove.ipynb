# %%
import pandas as pd

# %%
df=pd.read_csv('../../../car_data_500.csv').head()
df
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model   origin
# 0     76    Japan
# 1     73       US
# 2     80    India
# 3     77  Germany
# 4     74       US

# %% [markdown]
# # REmove Rows or Columns FRom DF
# - drop  => remove unwanted rows/columns
# - pop => we can reuse the removed rows/columns
# - truncate =>

# %% [markdown]
# # Drop

# %%
df.drop([0,1])
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model   origin
# 2     80    India
# 3     77  Germany
# 4     74       US

# %%
df
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model   origin
# 0     76    Japan
# 1     73       US
# 2     80    India
# 3     77  Germany
# 4     74       US

# %%
df=df.drop([0,3])

# %%
df
# Out:
#       car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 1  Jaguar  17.4       4.0          1793         186    2196        15.9
# 2    Audi  21.3       8.0          1943         265    3527         8.3
# 4    Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model origin
# 1     73     US
# 2     80  India
# 4     74     US

# %%
df=df.drop(['car'],axis=1)

# %%
df
# Out:
#     MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  Model origin
# 1  17.4       4.0          1793         186    2196        15.9     73     US
# 2  21.3       8.0          1943         265    3527         8.3     80  India
# 4  18.0       6.0          2968         140    2706         7.2     74     US

# %%
df.drop(['MPO'],axis=1,inplace=True)

# %%
df
# Out:
#    Cylinder  Displacement  Horsepower  weight  Accelarate  Model origin
# 1       4.0          1793         186    2196        15.9     73     US
# 2       8.0          1943         265    3527         8.3     80  India
# 4       6.0          2968         140    2706         7.2     74     US

# %%
df.drop(['Cylinder','Displacement'],axis=1,inplace=True)
df
# Out:
#    Horsepower  weight  Accelarate  Model origin
# 1         186    2196        15.9     73     US
# 2         265    3527         8.3     80  India
# 4         140    2706         7.2     74     US

# %%
df.drop(columns=['weight'],inplace=True)
df
# Out:
#    Horsepower  Accelarate  Model origin
# 1         186        15.9     73     US
# 2         265         8.3     80  India
# 4         140         7.2     74     US

# %%
df=df.drop(columns=['origin'])
df
# Out:
#    Horsepower  Accelarate  Model
# 1         186        15.9     73
# 2         265         8.3     80
# 4         140         7.2     74

# %% [markdown]
# # pop
# - we can reused the removed columns
# - we can pop only one at the time

# %%
df
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model   origin
# 0     76    Japan
# 1     73       US
# 2     80    India
# 3     77  Germany
# 4     74       US

# %%
df.pop('car')
# Out:
# 0       Ford
# 1     Jaguar
# 2       Audi
# 3    Hyundai
# 4       Tata
# Name: car, dtype: str

# %%
df
# Out:
#     MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  Model  \
# 0  20.7       6.0          1823         247    3374        15.5     76
# 1  17.4       4.0          1793         186    2196        15.9     73
# 2  21.3       8.0          1943         265    3527         8.3     80
# 3  11.5       6.0          4498         196    3317         9.9     77
# 4  18.0       6.0          2968         140    2706         7.2     74
#
#     origin
# 0    Japan
# 1       US
# 2    India
# 3  Germany
# 4       US

# %%
Cylinder=df.pop('Cylinder')
df
# Out:
#     MPO  Displacement  Horsepower  weight  Accelarate  Model   origin
# 0  20.7          1823         247    3374        15.5     76    Japan
# 1  17.4          1793         186    2196        15.9     73       US
# 2  21.3          1943         265    3527         8.3     80    India
# 3  11.5          4498         196    3317         9.9     77  Germany
# 4  18.0          2968         140    2706         7.2     74       US

# %%
Cylinder
# Out:
# 0    6.0
# 1    4.0
# 2    8.0
# 3    6.0
# 4    6.0
# Name: Cylinder, dtype: float64

# %% [markdown]
# # truncate

# %%
df
# Out:
#     MPO  Displacement  Horsepower  weight  Accelarate  Model   origin
# 0  20.7          1823         247    3374        15.5     76    Japan
# 1  17.4          1793         186    2196        15.9     73       US
# 2  21.3          1943         265    3527         8.3     80    India
# 3  11.5          4498         196    3317         9.9     77  Germany
# 4  18.0          2968         140    2706         7.2     74       US

# %%
df.truncate(2,3,axis=0)
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
#
#    Model   origin
# 2     80    India
# 3     77  Germany

# %%
df=df.truncate(2,3,axis=0)

# %%
df
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
#
#    Model   origin
# 2     80    India
# 3     77  Germany

# %%
df=df.truncate('MPO','Horsepower',axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 df=df.truncate('MPO','Horsepower',axis=1)
#
# File D:\Skillfort\SkillFortClass\env\env\Lib\site-packages\pandas\core\generic.py:10824, in NDFrame.truncate(self, before, after, axis, copy)
#   10820
#   10821         # GH 17935
#   10822         # Check that index is sorted
#   10823         if not ax.is_monotonic_increasing and not ax.is_monotonic_decreasing:
# > 10824             raise ValueError("truncate requires a sorted index")
#   10825
#   10826         # if we have a date index, convert to dates, otherwise
#   10827         # treat like a slice
#
# ValueError: truncate requires a sorted index

# %%
df=df.sort_index(axis=1)
df
# Out:
#    Accelarate  Cylinder  Displacement  Horsepower   MPO  Model      car  \
# 2         8.3       8.0          1943         265  21.3     80     Audi
# 3         9.9       6.0          4498         196  11.5     77  Hyundai
#
#     origin  weight
# 2    India    3527
# 3  Germany    3317

# %%
df=df.truncate('Cylinder','Model',axis=1)
df
# Out:
#    Cylinder  Displacement  Horsepower   MPO  Model
# 2       8.0          1943         265  21.3     80
# 3       6.0          4498         196  11.5     77

# %%
df=df.sort_index(axis=1,ascending=False)
df
# Out:
#    weight   origin      car  Model   MPO  Horsepower  Displacement  Cylinder  \
# 2    3527    India     Audi     80  21.3         265          1943       8.0
# 3    3317  Germany  Hyundai     77  11.5         196          4498       6.0
#
#    Accelarate
# 2         8.3
# 3         9.9
