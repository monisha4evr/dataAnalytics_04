# %%
import pandas as pd

# %%
df=pd.read_csv('../../../data.csv').head()
df
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df.dtypes
# Out:
# Duration      int64
# Pulse         int64
# Maxpulse      int64
# Calories    float64
# dtype: object

# %%
df.memory_usage()
# Out:
# Index       132
# Duration     40
# Pulse        40
# Maxpulse     40
# Calories     40
# dtype: int64

# %%
df['Calories']
# Out:
# 0    409.1
# 1    479.0
# 2    340.0
# 3    282.4
# 4    406.0
# Name: Calories, dtype: float64

# %%
df['Calories']=df['Calories'].astype('float32')
df['Calories']
# Out:
# 0    409.100006
# 1    479.000000
# 2    340.000000
# 3    282.399994
# 4    406.000000
# Name: Calories, dtype: float32

# %%
df['Calories']
# Out:
# 0    409.100006
# 1    479.000000
# 2    340.000000
# 3    282.399994
# 4    406.000000
# Name: Calories, dtype: float32

# %%
df=df.astype(
    {
        "Pulse":'int8', 
        "Maxpulse":'int8'
    }
)
df
# Out:
#    Duration  Pulse  Maxpulse    Calories
# 0        60    110      -126  409.100006
# 1        60    117      -111  479.000000
# 2        60    103      -121  340.000000
# 3        45    109       -81  282.399994
# 4        45    117      -108  406.000000

# %%
df.dtypes
# Out:
# Duration      int64
# Pulse          int8
# Maxpulse       int8
# Calories    float32
# dtype: object
