# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.5'

# %% [markdown]
# # Series and Dataframe
# - Series  (rows or Columns)
# - Dataframe (Rows and Columns)

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
pd.Series(['apple','orange','Banana'])
# Out:
# 0     apple
# 1    orange
# 2    Banana
# dtype: str

# %%
vegetables=pd.Series(('Brinjal','Potato','Tomato'))
vegetables.name="Vegetable"
vegetables
# Out:
# 0    Brinjal
# 1     Potato
# 2     Tomato
# Name: Vegetable, dtype: str

# %% [markdown]
# # Dataframe

# %% [markdown]
# ## Dataframe using List

# %%
fruit1=['apple','red',150]
fruit2=['Grapes','purple',50]
fruit3=['cherry','red',120]
fruits=[fruit1,fruit2,fruit3]
df=pd.DataFrame(fruits)
df.columns=["Name","Color","Price"]
df
# Out:
#      Name   Color  Price
# 0   apple     red    150
# 1  Grapes  purple     50
# 2  cherry     red    120

# %% [markdown]
# ## Dataframe using Tuple

# %%
fruit1=('apple','red',150)
fruit2=('Grapes','purple',50)
fruit3=('cherry','red',120)
fruits=[fruit1,fruit2,fruit3]
df=pd.DataFrame(fruits)
df.columns=["Name","Color","Price"]
df
# Out:
#      Name   Color  Price
# 0   apple     red    150
# 1  Grapes  purple     50
# 2  cherry     red    120

# %% [markdown]
# ## Dataframe using Dictionary

# %%
item={
    'fruits':['apple','orange','Banana'],
    "colors":['red','orange','yellow']
}
pd.DataFrame(item)
# Out:
#    fruits  colors
# 0   apple     red
# 1  orange  orange
# 2  Banana  yellow

# %% [markdown]
# # Path
# - 2 types
# - 1. Absolute path
# - 2. Relative

# %%
df=pd.read_csv(r'D:\Skillfort\SkillFortClass\data.csv')
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]
