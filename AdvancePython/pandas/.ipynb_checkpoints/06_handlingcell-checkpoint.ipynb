# %%
import pandas as pd

# %%
df=pd.read_csv('../../../car_data_500.csv').head()
df
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model   origin
# 0     76    Japan
# 1     73       US
# 2     80    India
# 3     77  Germany
# 4     74       US

# %% [markdown]
# # Get Cell Value

# %%
df.at[2,'car']
# Out:
# 'Audi'

# %%
df.at[3,'origin']
# Out:
# 'Germany'

# %%
df.iat[2,5]
# Out:
# np.int64(3527)

# %%
df.loc[2,'car']
# Out:
# 'Audi'

# %%
df.iloc[2,5]
# Out:
# np.int64(3527)

# %% [markdown]
# # Handling Rows

# %%
df.loc[2]
# Out:
# car              Audi
# MPO              21.3
# Cylinder          8.0
# Displacement     1943
# Horsepower        265
# weight           3527
# Accelarate        8.3
# Model              80
# origin          India
# Name: 2, dtype: object

# %%
df.loc[2]=['audi',21.3,8.0,1943,265,3527,8.3,80,'india']

# %%
df.loc[2]
# Out:
# car              audi
# MPO              21.3
# Cylinder          8.0
# Displacement     1943
# Horsepower        265
# weight           3527
# Accelarate        8.3
# Model              80
# origin          india
# Name: 2, dtype: object

# %%
df.loc[1:2]
# Out:
#       car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 1  Jaguar  17.4       4.0          1793         186    2196        15.9
# 2    audi  21.3       8.0          1943         265    3527         8.3
#
#    Model origin
# 1     73     US
# 2     80  india

# %%
df.loc[1:2]=[['jaguar',21.3,8.0,1943,265,3527,8.3,80,'us'],['Audi',21.3,8.0,1943,265,3527,8.3,80,'India']]

# %%
df.loc[1:2]
# Out:
#       car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 1  jaguar  21.3       8.0          1943         265    3527         8.3
# 2    Audi  21.3       8.0          1943         265    3527         8.3
#
#    Model origin
# 1     80     us
# 2     80  India

# %%
df.loc[[0,1,3]]
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 1   jaguar  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
#
#    Model   origin
# 0     76    Japan
# 1     80       us
# 3     77  Germany

# %% [markdown]
# # Handling Columns

# %%
df.loc[:,'car']
# Out:
# 0       Ford
# 1     jaguar
# 2       Audi
# 3    Hyundai
# 4       Tata
# Name: car, dtype: str

# %%
df.loc[:,'Displacement']
# Out:
# 0    1823
# 1    1943
# 2    1943
# 3    4498
# 4    2968
# Name: Displacement, dtype: int64

# %%
df.loc[:,'origin']
# Out:
# 0      Japan
# 1         us
# 2      India
# 3    Germany
# 4         US
# Name: origin, dtype: str

# %%
df.loc[:,'origin']='India'

# %%
df
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 1   jaguar  21.3       8.0          1943         265    3527         8.3
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model origin
# 0     76  India
# 1     80  India
# 2     80  India
# 3     77  India
# 4     74  India

# %%
df.loc[:,['origin','car','MPO']]
# Out:
#   origin      car   MPO
# 0  India     Ford  20.7
# 1  India   jaguar  21.3
# 2  India     Audi  21.3
# 3  India  Hyundai  11.5
# 4  India     Tata  18.0

# %%
df
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 1   jaguar  21.3       8.0          1943         265    3527         8.3
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model origin
# 0     76  India
# 1     80  India
# 2     80  India
# 3     77  India
# 4     74  India

# %%
df.loc[:,'Cylinder':'Accelarate']
# Out:
#    Cylinder  Displacement  Horsepower  weight  Accelarate
# 0       6.0          1823         247    3374        15.5
# 1       8.0          1943         265    3527         8.3
# 2       8.0          1943         265    3527         8.3
# 3       6.0          4498         196    3317         9.9
# 4       6.0          2968         140    2706         7.2

# %% [markdown]
# # adding Prefix and suffix

# %%
df.add_prefix('coln_',axis=0)
# Out:
#             car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# coln_0     Ford  20.7       6.0          1823         247    3374        15.5
# coln_1   jaguar  21.3       8.0          1943         265    3527         8.3
# coln_2     Audi  21.3       8.0          1943         265    3527         8.3
# coln_3  Hyundai  11.5       6.0          4498         196    3317         9.9
# coln_4     Tata  18.0       6.0          2968         140    2706         7.2
#
#         Model origin
# coln_0     76  India
# coln_1     80  India
# coln_2     80  India
# coln_3     77  India
# coln_4     74  India

# %%
df.add_suffix('_test',axis=0)
# Out:
#             car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0_test     Ford  20.7       6.0          1823         247    3374        15.5
# 1_test   jaguar  21.3       8.0          1943         265    3527         8.3
# 2_test     Audi  21.3       8.0          1943         265    3527         8.3
# 3_test  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4_test     Tata  18.0       6.0          2968         140    2706         7.2
#
#         Model origin
# 0_test     76  India
# 1_test     80  India
# 2_test     80  India
# 3_test     77  India
# 4_test     74  India

# %%
df.add_suffix('_test',axis=1)
# Out:
#   car_test  MPO_test  Cylinder_test  Displacement_test  Horsepower_test  \
# 0     Ford      20.7            6.0               1823              247
# 1   jaguar      21.3            8.0               1943              265
# 2     Audi      21.3            8.0               1943              265
# 3  Hyundai      11.5            6.0               4498              196
# 4     Tata      18.0            6.0               2968              140
#
#    weight_test  Accelarate_test  Model_test origin_test
# 0         3374             15.5          76       India
# 1         3527              8.3          80       India
# 2         3527              8.3          80       India
# 3         3317              9.9          77       India
# 4         2706              7.2          74       India

# %% [markdown]
# # Row index of min Value Based on Specific Column

# %%
df
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 1   jaguar  21.3       8.0          1943         265    3527         8.3
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model origin
# 0     76  India
# 1     80  India
# 2     80  India
# 3     77  India
# 4     74  India

# %%
df['Displacement'].idxmin()
# Out:
# 0

# %%
df['Cylinder'].idxmin()
# Out:
# 0

# %%
df['weight'].idxmax()
# Out:
# 1

# %%
df['MPO'].argmax()
# Out:
# np.int64(1)

# %%
df['MPO'].argmin()
# Out:
# np.int64(3)
