# %%
import pandas as pd

# %%
df=pd.read_csv('../../../car_data_500.csv')
df.head()
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model   origin
# 0     76    Japan
# 1     73       US
# 2     80    India
# 3     77  Germany
# 4     74       US

# %%
df.shape
# Out:
# (500, 9)

# %%
df['car'].shape
# Out:
# (500,)

# %%
df.columns
# Out:
# Index(['car', 'MPO', 'Cylinder', 'Displacement', 'Horsepower', 'weight',
#        'Accelarate', 'Model', 'origin'],
#       dtype='str')

# %%
df.values
# Out:
# array([['Ford', 20.7, 6.0, ..., 15.5, 76, 'Japan'],
#        ['Jaguar', 17.4, 4.0, ..., 15.9, 73, 'US'],
#        ['Audi', 21.3, 8.0, ..., 8.3, 80, 'India'],
#        ...,
#        ['Maruthi', 24.8, 4.0, ..., 12.5, 79, 'US'],
#        ['Tata', 12.2, 4.0, ..., 9.1, 79, 'South Korea'],
#        ['Honda', 17.0, 8.0, ..., 16.4, 79, 'US']],
#       shape=(500, 9), dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   car           500 non-null    str
#  1   MPO           500 non-null    float64
#  2   Cylinder      500 non-null    float64
#  3   Displacement  500 non-null    int64
#  4   Horsepower    500 non-null    int64
#  5   weight        500 non-null    int64
#  6   Accelarate    500 non-null    float64
#  7   Model         500 non-null    int64
#  8   origin        500 non-null    str
# dtypes: float64(3), int64(4), str(2)
# memory usage: 35.3 KB

# %%
df.dtypes
# Out:
# car                 str
# MPO             float64
# Cylinder        float64
# Displacement      int64
# Horsepower        int64
# weight            int64
# Accelarate      float64
# Model             int64
# origin              str
# dtype: object

# %%
df['car'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df.memory_usage()
# Out:
# Index            132
# car             4000
# MPO             4000
# Cylinder        4000
# Displacement    4000
# Horsepower      4000
# weight          4000
# Accelarate      4000
# Model           4000
# origin          4000
# dtype: int64

# %%
df.ndim
# Out:
# 2

# %%
df['car'].ndim
# Out:
# 1

# %%
df.index
# Out:
# RangeIndex(start=0, stop=500, step=1)

# %%
df['car'].index
# Out:
# RangeIndex(start=0, stop=500, step=1)

# %%
df['Horsepower'].dtypes
# Out:
# dtype('int64')

# %%
df['Horsepower'].size
# Out:
# 500

# %%
df.size
# Out:
# 4500

# %%
df['Horsepower'].count()
# Out:
# np.int64(500)

# %%
df.dtypes
# Out:
# car                 str
# MPO             float64
# Cylinder        float64
# Displacement      int64
# Horsepower        int64
# weight            int64
# Accelarate      float64
# Model             int64
# origin              str
# dtype: object
