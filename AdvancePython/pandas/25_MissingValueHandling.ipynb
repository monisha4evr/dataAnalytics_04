# %%
import pandas as pd

# %%
df=pd.read_csv('car_data.txt').head()
df
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247  3374.0        15.5
# 1   Jaguar  17.4       4.0          1793         186     NaN        15.9
# 2     Audi  21.3       8.0          1943         265  3527.0         8.3
# 3  Hyundai  11.5       NaN          4498         196  3317.0         9.9
# 4     Tata  18.0       NaN          2968         140  2706.0         7.2
#
#    Model   origin
# 0     76      NaN
# 1     73       US
# 2     80    India
# 3     77  Germany
# 4     74       US

# %%
df.isna() # true if null value Present
# Out:
#      car    MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0  False  False     False         False       False   False       False
# 1  False  False     False         False       False    True       False
# 2  False  False     False         False       False   False       False
# 3  False  False      True         False       False   False       False
# 4  False  False      True         False       False   False       False
#
#    Model  origin
# 0  False    True
# 1  False   False
# 2  False   False
# 3  False   False
# 4  False   False

# %%
df.isna().sum() #Based on Columnwise
# Out:
# car             0
# MPO             0
# Cylinder        2
# Displacement    0
# Horsepower      0
# weight          1
# Accelarate      0
# Model           0
# origin          1
# dtype: int64

# %%
df.isnull()
# df.isnull().sum()
# Out:
#      car    MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0  False  False     False         False       False   False       False
# 1  False  False     False         False       False    True       False
# 2  False  False     False         False       False   False       False
# 3  False  False      True         False       False   False       False
# 4  False  False      True         False       False   False       False
#
#    Model  origin
# 0  False    True
# 1  False   False
# 2  False   False
# 3  False   False
# 4  False   False

# %%
# Filter missing Values
df.loc[df['Horsepower'].isna()]
# Out:
# Empty DataFrame
# Columns: [car, MPO, Cylinder, Displacement, Horsepower, weight, Accelarate, Model, origin]
# Index: []

# %% [markdown]
# # Handle Missing Value

# %% [markdown]
# ## Drop missing Records

# %%
df
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247  3374.0        15.5
# 1   Jaguar  17.4       4.0          1793         186     NaN        15.9
# 2     Audi  21.3       8.0          1943         265  3527.0         8.3
# 3  Hyundai  11.5       NaN          4498         196  3317.0         9.9
# 4     Tata  18.0       NaN          2968         140  2706.0         7.2
#
#    Model   origin
# 0     76      NaN
# 1     73       US
# 2     80    India
# 3     77  Germany
# 4     74       US

# %%
df.dropna()
# df =df.dropna()
# df.dropna(inplace=True)
# Out:
#     car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  Model  \
# 2  Audi  21.3       8.0          1943         265  3527.0         8.3     80
#
#   origin
# 2  India

# %%
df.shape
# Out:
# (5, 9)

# %%
df=df.fillna(value=1000)

# %%
df
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247  3374.0        15.5
# 1   Jaguar  17.4       4.0          1793         186  1000.0        15.9
# 2     Audi  21.3       8.0          1943         265  3527.0         8.3
# 3  Hyundai  11.5    1000.0          4498         196  3317.0         9.9
# 4     Tata  18.0    1000.0          2968         140  2706.0         7.2
#
#    Model   origin
# 0     76     1000
# 1     73       US
# 2     80    India
# 3     77  Germany
# 4     74       US

# %%
df.loc[df['origin']==1000]
# Out:
#     car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  Model  \
# 0  Ford  20.7       6.0          1823         247  3374.0        15.5     76
#
#   origin
# 0   1000

# %%
df=pd.read_csv('car_data.csv').head(10)
df
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0           NaN         NaN  3374.0        15.5
# 1   Jaguar  17.4       4.0        1793.0       186.0     NaN        15.9
# 2     Audi  21.3       8.0           NaN       265.0     NaN         8.3
# 3  Hyundai   NaN       NaN        4498.0         NaN  3317.0         NaN
# 4   Toyota  18.0       NaN           NaN       140.0  2706.0         7.2
# 5      Kia  15.7       NaN        2659.0       155.0  3156.0        10.2
# 6   Toyota  16.9       8.0        3148.0       102.0  3974.0        15.5
# 7     Ford  19.1       8.0        4693.0       150.0  1800.0        12.7
# 8      BMW  17.5       6.0        3801.0       221.0  1818.0        10.8
# 9     Tata  18.1       6.0        3268.0       130.0  2383.0        11.1
#
#    Model       origin
# 0     76          NaN
# 1     73           US
# 2     80        India
# 3     77          NaN
# 4     74           US
# 5     76           US
# 6     79          NaN
# 7     72          NaN
# 8     76  South Korea
# 9     80        India

# %%
df.dropna()
# Out:
#     car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  Model  \
# 8   BMW  17.5       6.0        3801.0       221.0  1818.0        10.8     76
# 9  Tata  18.1       6.0        3268.0       130.0  2383.0        11.1     80
#
#         origin
# 8  South Korea
# 9        India

# %%
df.dropna(how="any")
# Out:
#     car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  Model  \
# 8   BMW  17.5       6.0        3801.0       221.0  1818.0        10.8     76
# 9  Tata  18.1       6.0        3268.0       130.0  2383.0        11.1     80
#
#         origin
# 8  South Korea
# 9        India

# %%
df.dropna(how="all")
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0           NaN         NaN  3374.0        15.5
# 1   Jaguar  17.4       4.0        1793.0       186.0     NaN        15.9
# 2     Audi  21.3       8.0           NaN       265.0     NaN         8.3
# 3  Hyundai   NaN       NaN        4498.0         NaN  3317.0         NaN
# 4   Toyota  18.0       NaN           NaN       140.0  2706.0         7.2
# 5      Kia  15.7       NaN        2659.0       155.0  3156.0        10.2
# 6   Toyota  16.9       8.0        3148.0       102.0  3974.0        15.5
# 7     Ford  19.1       8.0        4693.0       150.0  1800.0        12.7
# 8      BMW  17.5       6.0        3801.0       221.0  1818.0        10.8
# 9     Tata  18.1       6.0        3268.0       130.0  2383.0        11.1
#
#    Model       origin
# 0     76          NaN
# 1     73           US
# 2     80        India
# 3     77          NaN
# 4     74           US
# 5     76           US
# 6     79          NaN
# 7     72          NaN
# 8     76  South Korea
# 9     80        India

# %%
df.dropna(thresh=5)
# Out:
#       car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0    Ford  20.7       6.0           NaN         NaN  3374.0        15.5
# 1  Jaguar  17.4       4.0        1793.0       186.0     NaN        15.9
# 2    Audi  21.3       8.0           NaN       265.0     NaN         8.3
# 4  Toyota  18.0       NaN           NaN       140.0  2706.0         7.2
# 5     Kia  15.7       NaN        2659.0       155.0  3156.0        10.2
# 6  Toyota  16.9       8.0        3148.0       102.0  3974.0        15.5
# 7    Ford  19.1       8.0        4693.0       150.0  1800.0        12.7
# 8     BMW  17.5       6.0        3801.0       221.0  1818.0        10.8
# 9    Tata  18.1       6.0        3268.0       130.0  2383.0        11.1
#
#    Model       origin
# 0     76          NaN
# 1     73           US
# 2     80        India
# 4     74           US
# 5     76           US
# 6     79          NaN
# 7     72          NaN
# 8     76  South Korea
# 9     80        India

# %%
df.dropna(thresh=8)
# Out:
#       car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 1  Jaguar  17.4       4.0        1793.0       186.0     NaN        15.9
# 5     Kia  15.7       NaN        2659.0       155.0  3156.0        10.2
# 6  Toyota  16.9       8.0        3148.0       102.0  3974.0        15.5
# 7    Ford  19.1       8.0        4693.0       150.0  1800.0        12.7
# 8     BMW  17.5       6.0        3801.0       221.0  1818.0        10.8
# 9    Tata  18.1       6.0        3268.0       130.0  2383.0        11.1
#
#    Model       origin
# 1     73           US
# 5     76           US
# 6     79          NaN
# 7     72          NaN
# 8     76  South Korea
# 9     80        India

# %%
df.dropna(subset=['origin'])
# Out:
#       car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 1  Jaguar  17.4       4.0        1793.0       186.0     NaN        15.9
# 2    Audi  21.3       8.0           NaN       265.0     NaN         8.3
# 4  Toyota  18.0       NaN           NaN       140.0  2706.0         7.2
# 5     Kia  15.7       NaN        2659.0       155.0  3156.0        10.2
# 8     BMW  17.5       6.0        3801.0       221.0  1818.0        10.8
# 9    Tata  18.1       6.0        3268.0       130.0  2383.0        11.1
#
#    Model       origin
# 1     73           US
# 2     80        India
# 4     74           US
# 5     76           US
# 8     76  South Korea
# 9     80        India
