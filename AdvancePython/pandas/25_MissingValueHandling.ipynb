# %%
import pandas as pd

# %%
df=pd.read_csv('car_data.txt').head()
df
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247  3374.0        15.5
# 1   Jaguar  17.4       4.0          1793         186     NaN        15.9
# 2     Audi  21.3       8.0          1943         265  3527.0         8.3
# 3  Hyundai  11.5       NaN          4498         196  3317.0         9.9
# 4     Tata  18.0       NaN          2968         140  2706.0         7.2
#
#    Model   origin
# 0     76      NaN
# 1     73       US
# 2     80    India
# 3     77  Germany
# 4     74       US

# %%
df.isna() # true if null value Present
# Out:
#      car    MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0  False  False     False         False       False   False       False
# 1  False  False     False         False       False   False       False
# 2  False  False     False         False       False   False       False
# 3  False  False     False         False       False   False       False
# 4  False  False     False         False       False   False       False
#
#    Model  origin
# 0  False   False
# 1  False   False
# 2  False   False
# 3  False   False
# 4  False   False

# %%
df.isna().sum() #Based on Columnwise
# Out:
# car             0
# MPO             0
# Cylinder        0
# Displacement    0
# Horsepower      0
# weight          0
# Accelarate      0
# Model           0
# origin          0
# dtype: int64

# %%
df.isnull()
# df.isnull().sum()
# Out:
#      car    MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0  False  False     False         False       False   False       False
# 1  False  False     False         False       False   False       False
# 2  False  False     False         False       False   False       False
# 3  False  False     False         False       False   False       False
# 4  False  False     False         False       False   False       False
#
#    Model  origin
# 0  False   False
# 1  False   False
# 2  False   False
# 3  False   False
# 4  False   False

# %%
# Filter missing Values
df.loc[df['Horsepower'].isna()]
# Out:
# Empty DataFrame
# Columns: [car, MPO, Cylinder, Displacement, Horsepower, weight, Accelarate, Model, origin]
# Index: []

# %% [markdown]
# # Handle Missing Value

# %% [markdown]
# ## Drop missing Records

# %%
df.dropna()
# df =df.dropna()
# df.dropna(inplace=True)
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model   origin
# 0     76    Japan
# 1     73       US
# 2     80    India
# 3     77  Germany
# 4     74       US

# %%
df.shape
# Out:
# (5, 9)

# %%
df.fillna(value=1000)
# Out:
#        car   MPO  Cylinder  Displacement  Horsepower  weight  Accelarate  \
# 0     Ford  20.7       6.0          1823         247    3374        15.5
# 1   Jaguar  17.4       4.0          1793         186    2196        15.9
# 2     Audi  21.3       8.0          1943         265    3527         8.3
# 3  Hyundai  11.5       6.0          4498         196    3317         9.9
# 4     Tata  18.0       6.0          2968         140    2706         7.2
#
#    Model   origin
# 0     76    Japan
# 1     73       US
# 2     80    India
# 3     77  Germany
# 4     74       US

# %%
# fill 1000
df.loc[df['Cylinder']==1000]
# Out:
# Empty DataFrame
# Columns: [car, MPO, Cylinder, Displacement, Horsepower, weight, Accelarate, Model, origin]
# Index: []
