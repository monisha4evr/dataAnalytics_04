# %%
import pandas as pd

# %%
df=pd.read_csv('../../../data.csv').head()
df
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df_copy=df.copy()
df_copy
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df_copy.columns
# Out:
# Index(['Duration', 'Pulse', 'Maxpulse', 'Calories'], dtype='str')

# %%
df_copy.columns=['duration', 'Puls', 'M_pulse', 'Caloris']

# %%
df_copy
# Out:
#    duration  Puls  M_pulse  Caloris
# 0        60   110      130    409.1
# 1        60   117      145    479.0
# 2        60   103      135    340.0
# 3        45   109      175    282.4
# 4        45   117      148    406.0

# %%
df
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df_ref=df
df_ref
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df_ref.columns=['duration', 'pulse', 'Max_pulse', 'Caloris']
df_ref
# Out:
#    duration  pulse  Max_pulse  Caloris
# 0        60    110        130    409.1
# 1        60    117        145    479.0
# 2        60    103        135    340.0
# 3        45    109        175    282.4
# 4        45    117        148    406.0

# %%
df
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df.loc[2,'Duration']=50

# %%
df
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        50    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df.loc[0:2]=100
df
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0       100    100       100     100.0
# 1       100    100       100     100.0
# 2       100    100       100     100.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df.loc[0:2,'Pulse']=50
df
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0       100     50       100     100.0
# 1       100     50       100     100.0
# 2       100     50       100     100.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df.loc[2,['Duration','Maxpulse']]=90
df
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        80     50        80     100.0
# 1        80     50        80     100.0
# 2        90     50        90     100.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df['Duration']>=80
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# Name: Duration, dtype: bool

# %%
df.loc[df['Duration']>=80]
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        80     50        80     100.0
# 1        80     50        80     100.0
# 2        90     50        90     100.0
