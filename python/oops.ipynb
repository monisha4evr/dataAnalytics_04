# %% [markdown]
# oops => Object Oriented Programming
#
# class -> blue print
# object -> instance of class
# attribute
# method

# %%
Syntax: 
class Test:
    name="Babuji"
    city="Chennai"
# Out:
#   Cell In[11], line 1
#     Syntax:
#             ^
# SyntaxError: invalid syntax

# %%
Test.name
# Out:
# 'N'

# %%
Test.city
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 Test.city
#
# AttributeError: type object 'Test' has no attribute 'city'
